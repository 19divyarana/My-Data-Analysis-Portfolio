# %% [markdown]
# ### Advanced NumPy

# %% [markdown]
# ### 1. Broadcasting (VERY IMPORTANT)

# %% [markdown]
# - Allows operations on arrays of different shapes
# - Rules:
#
# - Match dimensions from right → left
# - Dimensions must be:
#
# - equal OR
# - one of them is 1

# %% [markdown]
# ### 2. Vectorization

# %% [markdown]
# - Replace loops with NumPy operations

# %% [markdown]
# ### 3. Handling Missing Data

# %% [markdown]
# - np.isnan(arr)
# - np.nanmean(arr)
# - np.nansum(arr)

# %% [markdown]
# ### 4.Random Module (Data Simulation)

# %% [markdown]
# - np.random.rand()
# - np.random.randint()
# - np.random.normal()
# - np.random.seed(42)
